# %% [markdown]
# <a href="https://colab.research.google.com/github/wevertonewald-blip/FComputa-o_1604/blob/main/Computacional_16_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def soma(a, b):
  '''
  helpeeeeeeeeeeee
  '''
  return a+b
def sub(a, b):
  return a-b
